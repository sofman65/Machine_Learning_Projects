# %% [markdown]
# # Time Series Forecasting

# %% [markdown]
# Time series forecasting is a crucial element of machine learning that is sometimes overlooked. Because there are so many prediction issues with a temporal component, it's critical. These issues are disregarded since the time component is what makes time series problems more difficult. In this project we are going to work on Time series, time series analysis, and time series forecasting and apply differet ML techniques while analyzing time series data.

# %% [markdown]
# # Time Series
#
# In standard machine learning datasets, time does play a role. When making predictions for new data, keep in mind that the actual outcome may not be available until a later date. Although the future is forecasted, all previous observations are given equal weight. Perhaps with some slight temporal dynamics to combat concept drift, such as using only the most recent year of observations rather than all available data.
# A time series dataset is not the same as a regular dataset. A time dimension is introduced by adding an explicit order dependence between observations in the form of a time series. This additional dimension serves as a constraint as well as a structure that gives extra information.

# %% [markdown]
# Before we go any further, it's vital to define the terminologies that are commonly used to describe time series data. The current time is denoted by the letter t, while an observation made at that time is denoted by the letter obs (t).  We are frequently interested in observations made at earlier times, which are referred to as lag times or lags.  In comparison to the present, past times are negative. The prior time, for example, is t-1 , and t-2 is the time before that. Obs(t-1) and obs(t-2) are the observations at these times (t-2)  respectively. Future times are what we're interested in forecasting, and they're looking well, in relation to the present moment The following time, for example, is t+1, and the time after that is t+2. Obs(t+1) and obs(t+2) are the observations at these times, respectively.

# %% [markdown]
# To sum it up:
#
# \begin{itemize}
#     \item t-n: A period of time that precedes or follows (e.g. t-1 for the previous time).
#     \item t: The current time and reference point.
#     \item t+n: A time in the future or forecast (for example, t+1 for the next time).
# \end{itemize}

# %% [markdown]
# # Forecasting
#
# Forecasting entails fitting models to historical data and then utilizing those models to forecast future events. Descriptive models can borrow from the future (for example, to smooth or eliminate noise), but they simply want to explain the facts as accurately as possible. The fact that the future is wholly unknown and can only be predicted from what has already occurred is a significant distinction in forecasting. The ability of a time series forecasting model to predict the future is defined by its performance.

# %% [markdown]
# # Components of Time Series
#
# Time series analysis is a collection of approaches that can be used to better understand a dataset. The segmentation of a time series into four main elements is perhaps the most useful of these:
#
# \begin{itemize}
#     \item Level :  If the series were a straight line, this would be the baseline value.
#     \item Trend : The series' optional and frequently linear increasing or decreasing behavior over time
#     \item Seasonality : Optional repeating patterns or cycles of activity throughout time
#     \item Noise : Variability in the observations that isn't explained by the model
# \end{itemize}

# %% [markdown]
# # Application
#
# In this project we are going to make an analysis of a specific dataset and apply different techniques to solve the problem of time series forcasting

# %% [markdown]
# # The problem
# The economic sector is one of the most important pillars of countries. Economic activities
# of industry are intimately linked with the ability to meet their needs for electricity. Therefore, electricity
# forecasting is a very important task. Accurate forecasts of electricity demand inform investment decisions
# about power generation and supporting network infrastructure. Of major interest to energy policymakers,
# power utilities, and private investors alike, forecasts are also essential for development professionals.

# %% [markdown]
# # The data
# The entire datasets are divided into 14 comma-separated value (csv) files according to the floor
# and year of the data recorded. Note that one CSV file is provided for each floor of the building. This makes
# the total of seven CSV files for each year. Since each file does include data of each zone on a single floor,
# a user has the flexibility to work with any individual zones, which can be extracted (based on the column
# names) from the CSV files.

# %% [markdown]
# Each file combines the measurements available in each zone on the same floor of the building in a particular
# year. These measurements are the electricity consumption (kW) of individual air conditioning (AC) units,
# lighting loads and plug loads, as well as the environmental sensor data, including indoor temperature (°C),
# relative humidity (%) and ambient light (lux). Note that the monitored loads do not include the two elevators
# and emergency exit signs. These loads added up to about 1–2 percent of the total building loads.
# Each of the 2018 data files has 264,960 rows, which indicate one-minute interval data (1,440 data
# points/day) for 184 days during the second half year of 2018. Each of the 2019 data files has 525,600
# rows, which indicate one-minute interval data (1,440 data points/day) for 365 days during the entire year of
# 2019.

# %% [markdown]
# The number of columns is different in each file, depending on the number of data measurements on the
# floor.
# For example, the files 2018Floor1.csv have 11 data columns, and one timestamp column. These 11 data
# columns are: Zone 1–Power consumption (kW) of lighting loads (one column); Zone 2–Power consumption
# (kW) of four individual AC units, one lighting load and one plug load (six columns); Zone 3–Power consumption (kW) of one lighting and one plug loads (two columns); and Zone 4–Power consumption (kW) of
# lighting and plug loads (two columns). Floor 1 has no sensor.
# For the specific analysis we use only the 2018Floor1.csv data set.

# %% [markdown]
# # The model
# Data in Time Series Forecasting (TSF) surveys are highly correlated because of the time
# factor. This is why it is of great importance for special models to be applied. Thus, we will use CNN FNN
# (Convolutional Neural Networks - Feedforward Neural Network), CNN GRU (Gated Recurrent Unit), CNN - LSTM (Long shortterm memory), CNN - Bidirectional LSTM, CNN - Bidirectional GRU.

# %% [markdown]
# # How the model will be evaluated
# We will split every dataframe resulting from our initial dataset in
# training and testing set. In this way we will fit our models with the training set and make predictions using
# the testing set. Next, we can compare the predictions with the real values using Mean Absolute Error (MAE)
# to conclude how valid every model’s results are.

# %% [markdown]
# # Anticipated challenges
# It is understandable that the big challenge in this dataset is to predict the values
# of all the variables for the next timestamp at the same time.

# %% [markdown]
# # The promise
# Through our analysis, we hope to investigate and evaluate a plethora of Deep Learning
# Architectures as well as various AutoML Algorithms so as to find the most efficient AI Models for energy
# consumption forecasting.

# %%
import lightgbm as lgb

import numpy as np 
import pandas as pd

import os
import time

import datetime as datetime

from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf


import os
import pandas as pd
import numpy as np
from keras import Sequential
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from os import walk
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

from random import random
from random import randint
from numpy import array
from numpy import zeros
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed

from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Activation
from keras.layers import RepeatVector
from keras.layers import Bidirectional
from keras.layers import GRU

from numpy import array
from numpy import hstack
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D


cf.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df =pd.read_csv("drive/My Drive/Elpida/2018Floor1.csv")

# %%
df.head(5)
# Out:
#                   Date  z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  \
# 0  2018-07-01 00:00:00         12.94        18.56       45.24        0.01
# 1  2018-07-01 00:01:00         12.97        18.55       45.28        0.02
# 2  2018-07-01 00:02:00         12.97        18.55       45.24        0.01
# 3  2018-07-01 00:03:00         12.98        18.58       45.26        0.02
# 4  2018-07-01 00:04:00         13.01        18.60       45.22        0.02
#
#    z2_AC3(kW)  z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  \
# 0        0.01        0.00         13.76        17.64         10.92
# 1        0.01        0.01         13.76        17.21         10.95
# 2        0.01        0.01         13.79        17.18         10.94
# 3        0.01        0.00         13.81        16.64         10.94
# 4        0.01        0.01         13.83        15.69         10.97
#
#    z3_Plug(kW)  z4_Light(kW)
# 0         0.89         35.76
# 1         0.87         35.81
# 2         0.86         35.78
# 3         0.85         35.83
# 4         0.85         35.86

# %% [markdown]
# # Pre-processing

# %%
df = df.sort_values('Date') # sort the 'Date' column
df.head(5)
# Out:
#                   Date  z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  \
# 0  2018-07-01 00:00:00         12.94        18.56       45.24        0.01
# 1  2018-07-01 00:01:00         12.97        18.55       45.28        0.02
# 2  2018-07-01 00:02:00         12.97        18.55       45.24        0.01
# 3  2018-07-01 00:03:00         12.98        18.58       45.26        0.02
# 4  2018-07-01 00:04:00         13.01        18.60       45.22        0.02
#
#    z2_AC3(kW)  z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  \
# 0        0.01        0.00         13.76        17.64         10.92
# 1        0.01        0.01         13.76        17.21         10.95
# 2        0.01        0.01         13.79        17.18         10.94
# 3        0.01        0.00         13.81        16.64         10.94
# 4        0.01        0.01         13.83        15.69         10.97
#
#    z3_Plug(kW)  z4_Light(kW)
# 0         0.89         35.76
# 1         0.87         35.81
# 2         0.86         35.78
# 3         0.85         35.83
# 4         0.85         35.86

# %%
print(df['Date'].min(), df['Date'].max()) # check the first and the last date
# Out:
# 2018-07-01 00:00:00 2018-12-31 23:59:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264960 entries, 0 to 264959
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          264960 non-null  object
#  1   z1_Light(kW)  263499 non-null  float64
#  2   z1_Plug(kW)   264474 non-null  float64
#  3   z2_AC1(kW)    263442 non-null  float64
#  4   z2_AC2(kW)    263503 non-null  float64
#  5   z2_AC3(kW)    263503 non-null  float64
#  6   z2_AC4(kW)    263503 non-null  float64
#  7   z2_Light(kW)  263526 non-null  float64
#  8   z2_Plug(kW)   235125 non-null  float64
#  9   z3_Light(kW)  264446 non-null  float64
#  10  z3_Plug(kW)   263503 non-null  float64
#  11  z4_Light(kW)  264445 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 26.3+ MB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.describe()
# Out:
#         z1_Light(kW)    z1_Plug(kW)     z2_AC1(kW)     z2_AC2(kW)  \
# count  263499.000000  264474.000000  263442.000000  263503.000000
# mean        6.388401       4.182152      29.007512       4.769192
# std         8.758483       6.938276      22.099131      12.370302
# min         0.000000       0.000000       0.010000       0.000000
# 25%         0.010000       0.640000       0.040000       0.020000
# 50%         0.020000       0.870000      44.280000       0.020000
# 75%        12.980000       1.260000      47.030000       0.030000
# max       134.970000      57.860000     131.550000     798.720000
#
#           z2_AC3(kW)     z2_AC4(kW)   z2_Light(kW)    z2_Plug(kW)  \
# count  263503.000000  263503.000000  263526.000000  235125.000000
# mean        0.009434       0.007446      14.754283      15.625258
# std         0.048780       0.008278       3.153056       2.595695
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.010000       0.000000      13.200000      14.360000
# 50%         0.010000       0.010000      14.800000      15.890000
# 75%         0.010000       0.010000      16.300000      17.090000
# max        24.950000       0.060000      55.280000      55.120000
#
#         z3_Light(kW)    z3_Plug(kW)   z4_Light(kW)
# count  264446.000000  263503.000000  264445.000000
# mean       23.582280       1.163607      17.114397
# std        16.837519       0.719731      18.517960
# min         0.000000       0.000000       0.000000
# 25%        13.240000       0.760000       0.060000
# 50%        20.770000       0.920000       9.910000
# 75%        27.410000       1.480000      34.010000
# max      4762.430000      22.220000     512.010000

# %%
df.isnull().sum() # check if there are any null values
# Out:
# Date                0
# z1_Light(kW)     1461
# z1_Plug(kW)       486
# z2_AC1(kW)       1518
# z2_AC2(kW)       1457
# z2_AC3(kW)       1457
# z2_AC4(kW)       1457
# z2_Light(kW)     1434
# z2_Plug(kW)     29835
# z3_Light(kW)      514
# z3_Plug(kW)      1457
# z4_Light(kW)      515
# dtype: int64

# %% [markdown]
# Replacing the null values with mean.

# %%
updated_df = df
df['z1_Light(kW)']=df['z1_Light(kW)'].fillna(df['z1_Light(kW)'].mean())

df['z1_Plug(kW)']=df['z1_Plug(kW)'].fillna(df['z1_Plug(kW)'].mean())

df['z2_AC1(kW)']=df['z2_AC1(kW)'].fillna(df['z2_AC1(kW)'].mean())

df['z2_AC2(kW)']=df['z2_AC2(kW)'].fillna(df['z2_AC2(kW)'].mean())

df['z2_AC3(kW)']=df['z2_AC3(kW)'].fillna(df['z2_AC3(kW)'].mean())

df['z2_AC4(kW)']=df['z2_AC4(kW)'].fillna(df['z2_AC4(kW)'].mean())

df['z2_Light(kW)']=df['z2_Light(kW)'].fillna(df['z2_Light(kW)'].mean())

df['z2_Plug(kW)']=df['z2_Plug(kW)'].fillna(df['z2_Plug(kW)'].mean())

df['z3_Light(kW)']=df['z3_Light(kW)'].fillna(df['z3_Light(kW)'].mean())

df['z3_Plug(kW)']=df['z3_Plug(kW)'].fillna(df['z3_Plug(kW)'].mean())

df['z4_Light(kW)']=df['z4_Light(kW)'].fillna(df['z4_Light(kW)'].mean())

# %%
df.isnull().sum()
# Out:
# Date            0
# z1_Light(kW)    0
# z1_Plug(kW)     0
# z2_AC1(kW)      0
# z2_AC2(kW)      0
# z2_AC3(kW)      0
# z2_AC4(kW)      0
# z2_Light(kW)    0
# z2_Plug(kW)     0
# z3_Light(kW)    0
# z3_Plug(kW)     0
# z4_Light(kW)    0
# dtype: int64

# %% [markdown]
# # EDA Analysis

# %%
df.set_index('Date').plot(style='.', figsize=(15,5), title='Consumption vs. Date')
plt.ylim([0, 1000])
plt.show()

# %%
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
f, ax = plt.subplots(figsize=(10, 6))

plt.plot(df['Date'][:1000], df['z1_Light(kW)'][:1000], label='z1_Light', color='orange')
plt.plot(df['Date'][:1000], df['z1_Plug(kW)'][:1000], label='z1_Plug', color='r')
plt.plot(df['Date'][:1000], df['z2_AC1(kW)'][:1000], label='z2_AC1', color='g')
plt.plot(df['Date'][:1000], df['z2_AC2(kW)'][:1000], label='z2_AC2', color='b')

plt.locator_params(axis='x', nbins=10)

ax.set_ylabel('Consumption')
ax.set_xlabel('Year')
ax.set_title('Consumption through time')
legend = plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=True, borderpad=1, borderaxespad=1)

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning:
#
# 'set_params()' not defined for locator of type <class 'matplotlib.dates.AutoDateLocator'>

# %%
fig, axs = plt.subplots(2, 2, figsize=(15,15))

axs[0, 0].plot(df['Date'], df['z1_Light(kW)'])
axs[0, 0].set_title('z1_Light consumption')
axs[0, 0].set_ylim([0, 400])
axs[0, 1].plot(df['Date'], df['z2_Light(kW)'], 'tab:orange')
axs[0, 1].set_title('z2_Light consumption')
axs[0, 1].set_ylim([0, 400])
axs[1, 0].plot(df['Date'], df['z3_Light(kW)'], 'tab:green')
axs[1, 0].set_title('z3_Light consumption')
axs[1, 0].set_ylim([0, 400])
axs[1, 1].plot(df['Date'], df['z4_Light(kW)'], 'tab:red')
axs[1, 1].set_title('z4_Light consumption')
axs[1, 1].set_ylim([0, 400])

for ax in axs.flat:
    ax.set(xlabel='time', ylabel='Consumption (kW)')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# # Split the dataset into train and test data

# %%
df['date'] =pd.to_datetime(df['Date'].dt.date)
update_df = df
update_df.drop(columns=['Date'])
# Out:
#         z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  z2_AC3(kW)  \
# 0              12.94        18.56       45.24        0.01        0.01
# 1              12.97        18.55       45.28        0.02        0.01
# 2              12.97        18.55       45.24        0.01        0.01
# 3              12.98        18.58       45.26        0.02        0.01
# 4              13.01        18.60       45.22        0.02        0.01
# ...              ...          ...         ...         ...         ...
# 264955          0.01         0.57       49.30        1.37        0.01
# 264956          0.01         0.57       45.44        1.36        0.01
# 264957          0.01         0.58        2.31        1.36        0.01
# 264958          0.02         0.57        2.31        1.35        0.00
# 264959          0.00         0.56        2.31        1.36        0.01
#
#         z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  z3_Plug(kW)  \
# 0             0.00         13.76        17.64         10.92         0.89
# 1             0.01         13.76        17.21         10.95         0.87
# 2             0.01         13.79        17.18         10.94         0.86
# 3             0.00         13.81        16.64         10.94         0.85
# 4             0.01         13.83        15.69         10.97         0.85
# ...            ...           ...          ...           ...          ...
# 264955        0.01         18.03        14.09         10.21         0.37
# 264956        0.00         17.72        11.37         10.13         0.38
# 264957        0.01         17.48        11.35         10.07         0.38
# 264958        0.00         17.43        11.39          9.99         0.37
# 264959        0.01         17.42        11.38         10.05         0.38
#
#         z4_Light(kW)       date  weekday  hour
# 0              35.76 2018-07-01        6     0
# 1              35.81 2018-07-01        6     0
# 2              35.78 2018-07-01        6     0
# 3              35.83 2018-07-01        6     0
# 4              35.86 2018-07-01        6     0
# ...              ...        ...      ...   ...
# 264955         14.58 2018-12-31        0    23
# 264956         14.60 2018-12-31        0    23
# 264957         14.57 2018-12-31        0    23
# 264958         14.59 2018-12-31        0    23
# 264959         14.59 2018-12-31        0    23
#
# [264960 rows x 14 columns]

# %%
df_temp = df
df_temp['weekday'] = df_temp['Date'].dt.weekday
df_temp['hour'] = df_temp['Date'].dt.hour
df_temp['date'] =pd.to_datetime(df_temp['Date'].dt.date)

df_temp = df_temp.set_index('Date').drop(['date'],axis=1)

# %%
traindata = df_temp.loc[:'2018-12'].copy()
traindata = traindata.iloc[:,0:11]

testdata = df_temp.loc['2018-12':'2018-12'].copy()
testdata = testdata.iloc[:,0:11]

# %% [markdown]
# # Normalize Data

# %% [markdown]
# Normalization is a data transformation process that aligns data values to a common scale or distribution of values so that. Normalization includes adjusting the scale of values to a similar metric or adjusting the time scales to be able to compare like periods.<br>
# In this case we use ***Min-Max Scaling*** which works by subtracting the minimum value from each column’s highest value and dividing by the range. Each new column has a minimum value of 0 and a maximum value of 1.

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()
traindata_norm = pd.DataFrame(min_max_scaler.fit_transform(traindata), columns=traindata.columns)
testdata_norm = pd.DataFrame(min_max_scaler.fit_transform(testdata), columns=testdata.columns)

traindata_norm
# Out:
#         z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  z2_AC3(kW)  \
# 0           0.095873     0.320774    0.343850    0.000013    0.000401
# 1           0.096095     0.320601    0.344154    0.000025    0.000401
# 2           0.096095     0.320601    0.343850    0.000013    0.000401
# 3           0.096170     0.321120    0.344002    0.000025    0.000401
# 4           0.096392     0.321466    0.343698    0.000025    0.000401
# ...              ...          ...         ...         ...         ...
# 264955      0.000074     0.009851    0.374715    0.001715    0.000401
# 264956      0.000074     0.009851    0.345370    0.001703    0.000401
# 264957      0.000074     0.010024    0.017485    0.001703    0.000401
# 264958      0.000148     0.009851    0.017485    0.001690    0.000000
# 264959      0.000000     0.009679    0.017485    0.001703    0.000401
#
#         z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  z3_Plug(kW)  \
# 0         0.000000      0.248915     0.320029      0.002293     0.040054
# 1         0.166667      0.248915     0.312228      0.002299     0.039154
# 2         0.166667      0.249457     0.311684      0.002297     0.038704
# 3         0.000000      0.249819     0.301887      0.002297     0.038254
# 4         0.166667      0.250181     0.284652      0.002303     0.038254
# ...            ...           ...          ...           ...          ...
# 264955    0.166667      0.326158     0.255624      0.002144     0.016652
# 264956    0.000000      0.320550     0.206277      0.002127     0.017102
# 264957    0.166667      0.316208     0.205914      0.002114     0.017102
# 264958    0.000000      0.315304     0.206640      0.002098     0.016652
# 264959    0.166667      0.315123     0.206459      0.002110     0.017102
#
#         z4_Light(kW)
# 0           0.069842
# 1           0.069940
# 2           0.069881
# 3           0.069979
# 4           0.070038
# ...              ...
# 264955      0.028476
# 264956      0.028515
# 264957      0.028456
# 264958      0.028496
# 264959      0.028496
#
# [264960 rows x 11 columns]

# %% [markdown]
# # Pre-prosessing Function for Sliding-Window

# %% [markdown]
# We utilize a sliding window technique transforming the time­series forecasting problem to a supervised one. More accurately, we obtain
# one flattened sequence and split it into several sub­sequences based on a sliding window with
# length 5000. Each subsequence is slided by one time-step.<br>
#
# In order to decrease the size from the original subsequence (5000), we calculate the mean value for every 10 values obtaining a 10 times smaller subsequence.

# %%
def decrease_seq(sequence, mean_batch=10):
  # reshape sequence
  seq = np.array(sequence).T

  new_sequence = []
  for j in seq:
      new_j = []

      temp_sum = 0
      for i,item in enumerate(j,start=1):
          temp_sum+=item
          if i%mean_batch == 0:
              mean_temp = temp_sum/mean_batch
              temp_sum=0
              new_j.append(mean_temp)
      new_sequence.append(new_j)
  return new_sequence

# %%
def extract_X_y_from_file(array, X_num, y_num):
    """ 
    Function that pre-process the data with a sliding-window supervised 
    learning approach extracting X and y

    - X_num: Input Window Length (N)
    - y_num: Number of prediction time-steps (M). We calculate the y as a mean 
              of the next M time-slots.
    """
    X = []
    y = []
    
    iterations = len(array)
    for i in range(0,iterations,30):
        if i%1000==0:
          print(i,'/',iterations)
        ### check if we reach to end
        if i+X_num + y_num > len(array):
            break          
        ### calculate X,y
        X_temp = array[i: i+X_num]
        # decrease seq
        new_X_temp = decrease_seq(X_temp)

        y_temp = array[i+X_num: i+X_num + y_num]
        y_temp = [y_temp[0][:11]]

        ### format y use mean
        new_y_temp = []
        # for every column
        for j in range(11):
            j_temp = []
            # for every row
            for i in range(y_num):
                row = y_temp[i][j]                

                j_temp.append(row)

            # obtain mean
            new_y_temp.append(np.mean(j_temp))                        
        # append
        X.append(new_X_temp)
        y.append(new_y_temp)        
        
    return X,y

# %%
def create_data(df, X_num = 5000, y_num = 1):
    """
    Function that reads all data csvs and calls the above mentioned function to
    extract X and y
    """
    all_X = []
    all_y = []

    # convert to list
    array = df.values.tolist()

    # create X and y
    X,y = extract_X_y_from_file(array, X_num, y_num)

    # add to final data
    all_X = all_X + X
    all_y = all_y + y

    return all_X, all_y

# %% [markdown]
# # Sliding-Window Approach
# Create windows of data with the sliding-window technique to construct a supervised learning problem.

# %% [markdown]
# # Training Data

# %%
X_train, y_train = create_data(df=traindata_norm)
# Out:
# e
# 0 / 264960
# 3000 / 264960
# 6000 / 264960
# 9000 / 264960
# 12000 / 264960
# 15000 / 264960
# 18000 / 264960
# 21000 / 264960
# 24000 / 264960
# 27000 / 264960
# 30000 / 264960
# 33000 / 264960
# 36000 / 264960
# 39000 / 264960
# 42000 / 264960
# 45000 / 264960
# 48000 / 264960
# 51000 / 264960
# 54000 / 264960
# 57000 / 264960
# 60000 / 264960
# 63000 / 264960
# 66000 / 264960
# 69000 / 264960
# 72000 / 264960
# 75000 / 264960
# 78000 / 264960
# 81000 / 264960
# 84000 / 264960
# 87000 / 264960
# 90000 / 264960
# 93000 / 264960
# 96000 / 264960
# 99000 / 264960
# 102000 / 264960
# 105000 / 264960
# 108000 / 264960
# 111000 / 264960
# 114000 / 264960
# 117000 / 264960
# 120000 / 264960
# 123000 / 264960
# 126000 / 264960
# 129000 / 264960
# 132000 / 264960
# 135000 / 264960
# 138000 / 264960
# 141000 / 264960
# 144000 / 264960
# 147000 / 264960
# 150000 / 264960
# 153000 / 264960
# 156000 / 264960
# 159000 / 264960
# 162000 / 264960
# 165000 / 264960
# 168000 / 264960
# 171000 / 264960
# 174000 / 264960
# 177000 / 264960
# 180000 / 264960
# 183000 / 264960
# 186000 / 264960
# 189000 / 264960
# 192000 / 264960
# 195000 / 264960
# 198000 / 264960
# 201000 / 264960
# 204000 / 264960
# 207000 / 264960
# 210000 / 264960
# 213000 / 264960
# 216000 / 264960
# 219000 / 264960
# 222000 / 264960
# 225000 / 264960
# 228000 / 264960
# 231000 / 264960
# 234000 / 264960
# 237000 / 264960
# 240000 / 264960
# 243000 / 264960
# 246000 / 264960
# 249000 / 264960
# 252000 / 264960
# 255000 / 264960
# 258000 / 264960

# %%
len(X_train)
# Out:
# 8666

# %%
len(y_train)
# Out:
# 8666

# %%
X_train = np.array(X_train)
X_train.shape
# Out:
# (8666, 11, 500)

# %%
y_train = np.array(y_train)
print(y_train.shape)
# Out:
# (8666, 11)

# %% [markdown]
# ## Testing Data

# %%
test_X = []
test_y = []

test_X, test_y = create_data(df=testdata_norm)

X_test = np.array(test_X)
print(X_test.shape)

y_test = np.array(test_y)
print(y_test.shape)
# Out:
# e
# 0 / 44640
# 3000 / 44640
# 6000 / 44640
# 9000 / 44640
# 12000 / 44640
# 15000 / 44640
# 18000 / 44640
# 21000 / 44640
# 24000 / 44640
# 27000 / 44640
# 30000 / 44640
# 33000 / 44640
# 36000 / 44640
# 39000 / 44640
# (1322, 11, 500)
# (1322, 11)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8666, 11, 500)
# (8666, 11)
# (1322, 11, 500)
# (1322, 11)

# %% [markdown]
# # CNN - FNN (Convolutional Neural Networks - Feedforward Neural Network)

# %% [markdown]
# **Convolutional Neural Networks** are a specific deep learning technique widely used in the
# field of computer vision. One of their primary characteristics is the use of kernel filters to extract low­level features from the input data by constructing a feature map. Moreover, they
# utilize pooling layers to extract dominant features, deal with the noise and perform dimensionality reduction resulting, this way, in a more efficient and faster model training. Finally,
# they also utilize fully connected layers and feed them with the information gathered from
# prior layers to learn a suitable non­linear function.<br>
#
# __For the models's implementation we use CNN because after selecting only specific features the training process will be faster and have better accuracy.__

# %% [markdown]
# **Feedforward Neural Networks (FNN)**are the first simple Artificial Neural
# Networks (ANN) that do not form node cycle connections and move forward from one layer.<br>
#
# The **structure** of NN consists of the input, several hidden, and
# the output layers. In addition, every layer contains numerous neuron nodes that connect with nodes in prior and following layers with weighted edges. Every neuron calculates its weighted
# input sum, and whether it is above or below a threshold value based on an activation function,
# it produces the appropriate output to the next layer.<BR>

# %% [markdown]
# **Feedforward Neural Networks** utilize the backpropagation approach to reduce their prediction error. Specifically, the model’s output is compared with the actual values, and the
# error is fed back to the network. It traverses the opposite­backward direction, adjusting the
# weights utilizing the gradient descent approach. This way, it finds the appropriate weights,
# enhancing the model’s predictive performance. We implement a Feedforward Neural Network utilizing the Tensorflow­Keras API.

# %% [markdown]
# A hybrid approach consisting of both CNN and FNN could result in a more robust and enhanced model. This technique is widely used in many research fields, such as activity recognition, image, and video description. The primary idea is to construct a type of encoderdecoder model architecture. Precisely, the CNN handles the feature extraction procedure, while the LSTM uses the features and analyzes their time sequence to make forecasting.

# %%
# define the model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(11,500)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(11))
model.compile(optimizer='adam', loss='mse')
model.summary()

# %%
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 9, 64)             96064
#
#  max_pooling1d_2 (MaxPooling  (None, 4, 64)            0
#  1D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 50)                12850
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 11)                561
#
# =================================================================
# Total params: 112,025
# Trainable params: 112,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 271/271 [==============================] - 4s 8ms/step - loss: 0.0052
# Epoch 2/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0030
# Epoch 3/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0027
# Epoch 4/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0025
# Epoch 5/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0023
# Epoch 6/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0022
# Epoch 7/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0022
# Epoch 8/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0021
# Epoch 9/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0021
# Epoch 10/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0020
# Epoch 11/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0020
# Epoch 12/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0020
# Epoch 13/300
# 271/271 [==============================] - 2s 7ms/step - loss: 0.0020
# Epoch 14/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0019
# Epoch 15/300
# 271/271 [==============================] - 2s 7ms/step - loss: 0.0019
# Epoch 16/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0019
# Epoch 17/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0018
# Epoch 18/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0018
# Epoch 19/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0018
# Epoch 20/300
# 271/271 [==============================] - 2s 7ms/step - loss: 0.0018
# Epoch 21/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0017
# Epoch 22/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0017
# Epoch 23/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0017
# Epoch 24/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0017
# Epoch 25/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0017
# Epoch 26/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0016
# Epoch 27/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0016
# Epoch 28/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0016
# Epoch 29/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0015
# Epoch 30/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0015
# Epoch 31/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0015
# Epoch 32/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0015
# Epoch 33/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0014
# Epoch 34/300
# 271/271 [==============================] - 2s 7ms/step - loss: 0.0014
# Epoch 35/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0014
# Epoch 36/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0014
# Epoch 37/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0014
# Epoch 38/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0013
# Epoch 39/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0013
# Epoch 40/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0013
# Epoch 41/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0013
# Epoch 42/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0012
# Epoch 43/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0013
# Epoch 44/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0012
# Epoch 45/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0012
# Epoch 46/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0012
# Epoch 47/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0012
# Epoch 48/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0012
# Epoch 49/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 50/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 51/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 52/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 53/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 54/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 55/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 56/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 57/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0010
# Epoch 58/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0010
# Epoch 59/300
# 271/271 [==============================] - 2s 8ms/step - loss: 0.0011
# Epoch 60/300
# 271/271 [==============================] - 2s 7ms/step - loss: 0.0010
# Epoch 61/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.9973e-04
# Epoch 62/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.8919e-04
# Epoch 63/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.9097e-04
# Epoch 64/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.9230e-04
# Epoch 65/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.8016e-04
# Epoch 66/300
# 271/271 [==============================] - 2s 8ms/step - loss: 9.6189e-04
# Epoch 67/300
# 271/271 [==============================] - 2s 8ms/step - loss: 9.4265e-04
# Epoch 68/300
# 271/271 [==============================] - 2s 8ms/step - loss: 9.4509e-04
# Epoch 69/300
# 271/271 [==============================] - 2s 7ms/step - loss: 0.0010
# Epoch 70/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.3499e-04
# Epoch 71/300
# 271/271 [==============================] - 2s 8ms/step - loss: 9.5474e-04
# Epoch 72/300
# 271/271 [==============================] - 2s 8ms/step - loss: 9.3991e-04
# Epoch 73/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.3252e-04
# Epoch 74/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.2646e-04
# Epoch 75/300
# 271/271 [==============================] - 2s 7ms/step - loss: 8.9833e-04
# Epoch 76/300
# 271/271 [==============================] - 2s 7ms/step - loss: 8.8637e-04
# Epoch 77/300
# 271/271 [==============================] - 2s 7ms/step - loss: 8.9803e-04
# Epoch 78/300
# 271/271 [==============================] - 2s 7ms/step - loss: 9.0843e-04
# Epoch 79/300
#  38/271 [===>..........................] - ETA: 1s - loss: 8.1138e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-a99ba91cfda7> in <module>()
# ----> 1 model.fit(X_train,y_train,epochs=300)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Training Evaluation

# %%
yhat_training = model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_train, yhat_training)
print('RMSE training',rms)

mae = mean_absolute_error(y_train, yhat_training)
print('MAE: training',mae)
# Out:
# RMSE training 0.000851200813878986
# MAE: training 0.01491603108850345

# %%
y_data_inv = min_max_scaler.inverse_transform(y_train)
yhat_training_inv = min_max_scaler.inverse_transform(yhat_training)

mae_inv = mean_absolute_error(y_data_inv.T, yhat_training_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 0.4522514009391274

# %%
mae_inv = mean_absolute_error(y_data_inv.T[0], yhat_training_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 0.35863485872898937

# %%
plt.figure(figsize=[15,5])
plt.plot(y_data_inv.T[0])
plot = plt.plot(yhat_training_inv.T[0])
plt.ylim([0,20])
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %% [markdown]
# # Testing Evaluation

# %%
yhat_testing = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_test, yhat_testing)
print('RMSE training',rms)

mae = mean_absolute_error(y_test, yhat_testing)
print('MAE: training',mae)
# Out:
# RMSE training 0.07300903274673086
# MAE: training 0.1818058961034551

# %%
y_test_inv = min_max_scaler.inverse_transform(y_test)
yhat_testing_inv = min_max_scaler.inverse_transform(yhat_testing)

mae_inv = mean_absolute_error(y_test_inv.T, yhat_testing_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 6.591129536680854

# %%
mae_inv = mean_absolute_error(y_test_inv.T[0], yhat_testing_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 1.7946235711358498

# %%
plt.figure(figsize=[15,5])
plt.plot(y_test_inv.T[0])
plot = plt.plot(yhat_testing_inv.T[0])
plt.ylim([0,35])
plt.xlim([0,1300])
# Out:
# (0.0, 1300.0)

# %% [markdown]
# # CNN - GRU (Gated Recurrent Unit)

# %% [markdown]
# Gated Recurrent Unit (GRU) is another popular type of Recurrent Neural Network similar to LSTM. It utilizes a gated mechanism to form both long­ and short­term memory by
# incorporating two gates, including the reset and the update gate. Thus, its difference from
# LSTM is that it does not use an output gate employing, this way, less trainable parameters.
# This approach often results in a similar performance to the LSTM but with faster training.
# We implement a GRU Neural Network utilizing the Tensorflow­Keras API.

# %% [markdown]
# A hybrid approach consisting of both CNN and GRU could result in a more robust and enhanced model. This technique is widely used in many research fields, such as activity recognition, image, and video description. The primary idea is to construct a type of encoderdecoder model architecture. Precisely, the CNN handles the feature extraction procedure, while the LSTM uses the features and analyzes their time sequence to make forecasting.

# %%
# define the model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(11,500)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(RepeatVector(1))
model.add(GRU(50, activation='relu',  return_sequences=True))
model.add(GRU(50, activation='relu'))
model.add(Dense(11))
model.compile(optimizer='adam', loss='mse')
model.summary()

# %%
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 9, 64)             96064
#
#  max_pooling1d (MaxPooling1D  (None, 4, 64)            0
#  )
#
#  flatten (Flatten)           (None, 256)               0
#
#  repeat_vector (RepeatVector  (None, 1, 256)           0
#  )
#
#  gru (GRU)                   (None, 1, 50)             46200
#
#  gru_1 (GRU)                 (None, 50)                15300
#
#  dense (Dense)               (None, 11)                561
#
# =================================================================
# Total params: 158,125
# Trainable params: 158,125
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 271/271 [==============================] - 6s 10ms/step - loss: 0.0045
# Epoch 2/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0027
# Epoch 3/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0024
# Epoch 4/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0022
# Epoch 5/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0022
# Epoch 6/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0021
# Epoch 7/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0020
# Epoch 8/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0020
# Epoch 9/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0020
# Epoch 10/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0019
# Epoch 11/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0019
# Epoch 12/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0018
# Epoch 13/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0018
# Epoch 14/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0018
# Epoch 15/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0018
# Epoch 16/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0017
# Epoch 17/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0017
# Epoch 18/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0017
# Epoch 19/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0016
# Epoch 20/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0016
# Epoch 21/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0016
# Epoch 22/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0016
# Epoch 23/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0015
# Epoch 24/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0015
# Epoch 25/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0014
# Epoch 26/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0014
# Epoch 27/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0014
# Epoch 28/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0014
# Epoch 29/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0013
# Epoch 30/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0013
# Epoch 31/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0013
# Epoch 32/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0013
# Epoch 33/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 34/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 35/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 36/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 37/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 38/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0011
# Epoch 39/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0011
# Epoch 40/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0011
# Epoch 41/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0011
# Epoch 42/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0011
# Epoch 43/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0011
# Epoch 44/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0010
# Epoch 45/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0010
# Epoch 46/300
# 271/271 [==============================] - 3s 10ms/step - loss: 9.9007e-04
# Epoch 47/300
# 271/271 [==============================] - 3s 10ms/step - loss: 9.8717e-04
# Epoch 48/300
# 271/271 [==============================] - 3s 10ms/step - loss: 9.6696e-04
# Epoch 49/300
# 271/271 [==============================] - 3s 10ms/step - loss: 9.5542e-04
# Epoch 50/300
# 271/271 [==============================] - 3s 10ms/step - loss: 9.4685e-04
# Epoch 51/300
# 271/271 [==============================] - 3s 10ms/step - loss: 9.4322e-04
# Epoch 52/300
# 271/271 [==============================] - 3s 10ms/step - loss: 9.2096e-04
# Epoch 53/300
# 271/271 [==============================] - 3s 10ms/step - loss: 8.8804e-04
# Epoch 54/300
# 271/271 [==============================] - 3s 10ms/step - loss: 8.8134e-04
# Epoch 55/300
# 271/271 [==============================] - 3s 10ms/step - loss: 8.6709e-04
# Epoch 56/300
# 271/271 [==============================] - 3s 11ms/step - loss: 8.5838e-04
# Epoch 57/300
# 271/271 [==============================] - 4s 14ms/step - loss: 8.4448e-04
# Epoch 58/300
# 271/271 [==============================] - 3s 10ms/step - loss: 8.4222e-04
# Epoch 59/300
# 105/271 [==========>...................] - ETA: 1s - loss: 8.6736e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-a99ba91cfda7> in <module>()
# ----> 1 model.fit(X_train,y_train,epochs=300)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Training Evaluation

# %%
yhat_training = model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_train, yhat_training)
print('RMSE training',rms)

mae = mean_absolute_error(y_train, yhat_training)
print('MAE: training',mae)
# Out:
# RMSE training 0.0007633081779096711
# MAE: training 0.013907212518490513

# %%
y_data_inv = min_max_scaler.inverse_transform(y_train)
yhat_training_inv = min_max_scaler.inverse_transform(yhat_training)

mae_inv = mean_absolute_error(y_data_inv.T, yhat_training_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 0.3863384576107062

# %%
mae_inv = mean_absolute_error(y_data_inv.T[0], yhat_training_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 0.2900689812397235

# %%
plt.figure(figsize=[15,5])
plt.plot(y_data_inv.T[0])
plot = plt.plot(yhat_training_inv.T[0])
plt.ylim([0,20])
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %% [markdown]
# # Testing Evaluation

# %%
yhat_testing = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_test, yhat_testing)
print('RMSE training',rms)

mae = mean_absolute_error(y_test, yhat_testing)
print('MAE: training',mae)
# Out:
# RMSE training 0.0689762085858852
# MAE: training 0.17920350339014768

# %%
y_test_inv = min_max_scaler.inverse_transform(y_test)
yhat_testing_inv = min_max_scaler.inverse_transform(yhat_testing)

mae_inv = mean_absolute_error(y_test_inv.T, yhat_testing_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 6.565690238996064

# %%
mae_inv = mean_absolute_error(y_test_inv.T[0], yhat_testing_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 2.1092127496722815

# %%
plt.figure(figsize=[15,5])
plt.plot(y_test_inv.T[0])
plot = plt.plot(yhat_testing_inv.T[0])
plt.ylim([0,35])
plt.xlim([0,1300])
# Out:
# (0.0, 1300.0)

# %% [markdown]
# # CNN - LSTM (Long short­term memory)

# %% [markdown]
# **Long Short­Term Memory (LSTM) networks** are a specific type of Recurrent Neural
# Networks (RNN) widely used for Time Series Forecasting and sequence prediction problems. They are very robust and often outperform other algorithms such as simple Feedforward
# NNs by employing memory components or conventional RNNs by dealing with the vanishing
# gradient problem.<br>
# The key enabler of their success is their unique design. An LSTM layer comprises numerous memory blocks which contain one or more recurrent memory cells and three units;
# the input, output, and forget gates. These gates continuously provide write, read, and reset
# methods to the cell based on the associated weights calculated during the training. This way,
# the model is able to adapt appropriately to the problem at hand by memorizing values over
# arbitrary time intervals.
# We implement an LSTM Neural Network utilizing the Tensorflow­Keras API.

# %% [markdown]
# A hybrid approach consisting of both CNN and LSTM could result in a more robust
# and enhanced model. This technique is widely used in many research fields, such as activity
# recognition, image, and video description. The primary idea is to construct a type of encoderdecoder model architecture. Precisely, the CNN handles the feature extraction procedure,
# while the LSTM uses the features and analyzes their time sequence to make forecasting.

# %%
# define the model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(11,500)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(RepeatVector(1))
model.add(LSTM(50, activation='relu',  return_sequences=True))
model.add(LSTM(50, activation='relu'))
model.add(Dense(11))
model.compile(optimizer='adam', loss='mse')
model.summary()

# %%
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_15 (Conv1D)          (None, 9, 64)             96064
#
#  max_pooling1d_15 (MaxPoolin  (None, 4, 64)            0
#  g1D)
#
#  flatten_15 (Flatten)        (None, 256)               0
#
#  repeat_vector_15 (RepeatVec  (None, 1, 256)           0
#  tor)
#
#  lstm_30 (LSTM)              (None, 1, 50)             61400
#
#  lstm_31 (LSTM)              (None, 50)                20200
#
#  dense_15 (Dense)            (None, 11)                561
#
# =================================================================
# Total params: 178,225
# Trainable params: 178,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 271/271 [==============================] - 6s 11ms/step - loss: 0.0050
# Epoch 2/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0029
# Epoch 3/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0025
# Epoch 4/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0023
# Epoch 5/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0022
# Epoch 6/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0021
# Epoch 7/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0021
# Epoch 8/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0020
# Epoch 9/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0020
# Epoch 10/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0019
# Epoch 11/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0019
# Epoch 12/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0019
# Epoch 13/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0018
# Epoch 14/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0018
# Epoch 15/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0018
# Epoch 16/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0018
# Epoch 17/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0018
# Epoch 18/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0017
# Epoch 19/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0017
# Epoch 20/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0017
# Epoch 21/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0016
# Epoch 22/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0016
# Epoch 23/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0016
# Epoch 24/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0015
# Epoch 25/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0015
# Epoch 26/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0015
# Epoch 27/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0015
# Epoch 28/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0014
# Epoch 29/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0014
# Epoch 30/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0014
# Epoch 31/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0014
# Epoch 32/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0013
# Epoch 33/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0013
# Epoch 34/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0012
# Epoch 35/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 36/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0012
# Epoch 37/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0012
# Epoch 38/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0012
# Epoch 39/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 40/300
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0012
# Epoch 41/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0011
# Epoch 42/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0011
# Epoch 43/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0011
# Epoch 44/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0011
# Epoch 45/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0010
# Epoch 46/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0010
# Epoch 47/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0010
# Epoch 48/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0010
# Epoch 49/300
# 271/271 [==============================] - 3s 11ms/step - loss: 0.0010
# Epoch 50/300
# 271/271 [==============================] - 3s 11ms/step - loss: 9.6337e-04
# Epoch 51/300
# 271/271 [==============================] - 3s 11ms/step - loss: 9.4998e-04
# Epoch 52/300
# 271/271 [==============================] - 3s 11ms/step - loss: 9.6287e-04
# Epoch 53/300
# 271/271 [==============================] - 3s 11ms/step - loss: 9.3387e-04
# Epoch 54/300
# 271/271 [==============================] - 3s 11ms/step - loss: 9.0481e-04
# Epoch 55/300
# 271/271 [==============================] - 3s 11ms/step - loss: 9.2298e-04
# Epoch 56/300
# 271/271 [==============================] - 3s 11ms/step - loss: 8.7973e-04
# Epoch 57/300
# 242/271 [=========================>....] - ETA: 0s - loss: 8.9083e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-299-a99ba91cfda7> in <module>()
# ----> 1 model.fit(X_train,y_train,epochs=300)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Training Evaluation

# %%
yhat_training = model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_train, yhat_training)
print('RMSE training',rms)

mae = mean_absolute_error(y_train, yhat_training)
print('MAE: training',mae)
# Out:
# RMSE training 0.0010242859919252052
# MAE: training 0.01664985097196855

# %%
y_data_inv = min_max_scaler.inverse_transform(y_train)
yhat_training_inv = min_max_scaler.inverse_transform(yhat_training)

mae_inv = mean_absolute_error(y_data_inv.T, yhat_training_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 0.4587696338802348

# %%
mae_inv = mean_absolute_error(y_data_inv.T[0], yhat_training_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 0.3204634138820291

# %%
plt.figure(figsize=[15,5])
plt.plot(y_data_inv.T[0])
plot = plt.plot(yhat_training_inv.T[0])
plt.ylim([0,20])
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %% [markdown]
# # Testing Evaluation

# %%
yhat_testing = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_test, yhat_testing)
print('RMSE training',rms)

mae = mean_absolute_error(y_test, yhat_testing)
print('MAE: training',mae)
# Out:
# RMSE training 0.07472124295412398
# MAE: training 0.19137769327091023

# %%
y_test_inv = min_max_scaler.inverse_transform(y_test)
yhat_testing_inv = min_max_scaler.inverse_transform(yhat_testing)

mae_inv = mean_absolute_error(y_test_inv.T, yhat_testing_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 7.125566200480572

# %%
mae_inv = mean_absolute_error(y_test_inv.T[0], yhat_testing_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 3.2455288215864124

# %%
plt.figure(figsize=[15,5])
plt.plot(y_test_inv.T[0])
plot = plt.plot(yhat_testing_inv.T[0])
plt.ylim([0,35])
plt.xlim([0,1300])
# Out:
# (0.0, 1300.0)

# %% [markdown]
# # CNN - Bidirectional LSTM

# %% [markdown]
# **Bi­directional LSTMs** extend the simple LSTMs providing an additional reversed sequence learning. Precisely, the main idea is incorporating two recurrent layers side­by­side,
# where the first one handles the original sequence as it is, while the second uses it in the opposite direction. This way, the model could acquire information both from the past and future
# simultaneously. This technique is utilized in various applications and often enables enhanced
# predictive performance.
# We implement a Bi­directional LSTM Neural Network utilizing the Tensorflow­Keras
# API.

# %%
# define the model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(11,500)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(RepeatVector(1))
model.add(Bidirectional(LSTM(25, activation='relu',  return_sequences=True) ))
model.add(Bidirectional(LSTM(25, activation='relu') ))
model.add(Dense(11))
model.compile(optimizer='adam', loss='mse')
model.summary()

# %%
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 9, 64)             96064
#
#  max_pooling1d_3 (MaxPooling  (None, 4, 64)            0
#  1D)
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  repeat_vector_1 (RepeatVect  (None, 1, 256)           0
#  or)
#
#  bidirectional (Bidirectiona  (None, 1, 50)            56400
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 50)               15200
#  nal)
#
#  dense_6 (Dense)             (None, 11)                561
#
# =================================================================
# Total params: 168,225
# Trainable params: 168,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 271/271 [==============================] - 8s 12ms/step - loss: 0.0047
# Epoch 2/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0028
# Epoch 3/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0025
# Epoch 4/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0023
# Epoch 5/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0022
# Epoch 6/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0021
# Epoch 7/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0021
# Epoch 8/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0020
# Epoch 9/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0019
# Epoch 10/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0019
# Epoch 11/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0019
# Epoch 12/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0018
# Epoch 13/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0018
# Epoch 14/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0018
# Epoch 15/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0018
# Epoch 16/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0018
# Epoch 17/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0017
# Epoch 18/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0017
# Epoch 19/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0017
# Epoch 20/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0016
# Epoch 21/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0016
# Epoch 22/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0016
# Epoch 23/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0015
# Epoch 24/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0015
# Epoch 25/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0015
# Epoch 26/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0015
# Epoch 27/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0014
# Epoch 28/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0014
# Epoch 29/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0014
# Epoch 30/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0013
# Epoch 31/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0013
# Epoch 32/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0013
# Epoch 33/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0013
# Epoch 34/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0013
# Epoch 35/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0012
# Epoch 36/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0012
# Epoch 37/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0012
# Epoch 38/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0012
# Epoch 39/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0011
# Epoch 40/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0011
# Epoch 41/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0011
# Epoch 42/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0011
# Epoch 43/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0011
# Epoch 44/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0011
# Epoch 45/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0010
# Epoch 46/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0010
# Epoch 47/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0010
# Epoch 48/300
# 271/271 [==============================] - 3s 12ms/step - loss: 9.9976e-04
# Epoch 49/300
# 271/271 [==============================] - 3s 12ms/step - loss: 9.6285e-04
# Epoch 50/300
# 271/271 [==============================] - 3s 12ms/step - loss: 9.6237e-04
# Epoch 51/300
# 271/271 [==============================] - 5s 18ms/step - loss: 9.4229e-04
# Epoch 52/300
# 271/271 [==============================] - 3s 13ms/step - loss: 9.1582e-04
# Epoch 53/300
# 271/271 [==============================] - 3s 13ms/step - loss: 9.0807e-04
# Epoch 54/300
# 271/271 [==============================] - 3s 12ms/step - loss: 8.9890e-04
# Epoch 55/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.6276e-04
# Epoch 56/300
# 271/271 [==============================] - 3s 12ms/step - loss: 8.6147e-04
# Epoch 57/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.4372e-04
# Epoch 58/300
# 271/271 [==============================] - 3s 12ms/step - loss: 8.2706e-04
# Epoch 59/300
#  46/271 [====>.........................] - ETA: 2s - loss: 7.8122e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-a99ba91cfda7> in <module>()
# ----> 1 model.fit(X_train,y_train,epochs=300)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Training Evaluation

# %%
yhat_training = model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_train, yhat_training)
print('RMSE training',rms)

mae = mean_absolute_error(y_train, yhat_training)
print('MAE: training',mae)
# Out:
# RMSE training 0.0007524274939753092
# MAE: training 0.014367996064038817

# %%
y_data_inv = min_max_scaler.inverse_transform(y_train)
yhat_training_inv = min_max_scaler.inverse_transform(yhat_training)

mae_inv = mean_absolute_error(y_data_inv.T, yhat_training_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 0.4057849947308125

# %%
mae_inv = mean_absolute_error(y_data_inv.T[0], yhat_training_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 0.3259231643945571

# %%
plt.figure(figsize=[15,5])
plt.plot(y_data_inv.T[0])
plot = plt.plot(yhat_training_inv.T[0])
plt.ylim([0,20])
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %% [markdown]
# # Testing Evaluation

# %%
yhat_testing = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_test, yhat_testing)
print('RMSE training',rms)

mae = mean_absolute_error(y_test, yhat_testing)
print('MAE: training',mae)
# Out:
# RMSE training 0.09492738860364387
# MAE: training 0.21004411261802397

# %%
y_test_inv = min_max_scaler.inverse_transform(y_test)
yhat_testing_inv = min_max_scaler.inverse_transform(yhat_testing)

mae_inv = mean_absolute_error(y_test_inv.T, yhat_testing_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 7.776813779579916

# %%
mae_inv = mean_absolute_error(y_test_inv.T[0], yhat_testing_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 2.771047871663086

# %%
plt.figure(figsize=[15,5])
plt.plot(y_test_inv.T[0])
plot = plt.plot(yhat_testing_inv.T[0])
plt.ylim([0,35])
plt.xlim([0,1300])
# Out:
# (0.0, 1300.0)

# %% [markdown]
# # CNN - Bidirectional GRU

# %% [markdown]
# Bi­directional GRUs extend the simple GRUs providing an additional reversed sequence learning. Precisely, the main idea is incorporating two recurrent layers side­by­side, where the first one handles the original sequence as it is, while the second uses it in the opposite direction. This way, the model could acquire information both from the past and future simultaneously. This technique is utilized in various applications and often enables enhanced predictive performance. We implement a Bi­directional GRU Neural Network utilizing the Tensorflow­Keras API.

# %%
# define the model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(11,500)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(RepeatVector(1))
model.add(Bidirectional(GRU(25, activation='relu',  return_sequences=True) ))
model.add(Bidirectional(GRU(25, activation='relu') ))
model.add(Dense(11))
model.compile(optimizer='adam', loss='mse')
model.summary()

# %%
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 9, 64)             96064
#
#  max_pooling1d_4 (MaxPooling  (None, 4, 64)            0
#  1D)
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  repeat_vector_2 (RepeatVect  (None, 1, 256)           0
#  or)
#
#  bidirectional_2 (Bidirectio  (None, 1, 50)            42450
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 50)               11550
#  nal)
#
#  dense_7 (Dense)             (None, 11)                561
#
# =================================================================
# Total params: 150,625
# Trainable params: 150,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 271/271 [==============================] - 9s 13ms/step - loss: 0.0043
# Epoch 2/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0028
# Epoch 3/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0025
# Epoch 4/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0023
# Epoch 5/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0022
# Epoch 6/300
# 271/271 [==============================] - 4s 14ms/step - loss: 0.0021
# Epoch 7/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0020
# Epoch 8/300
# 271/271 [==============================] - 4s 14ms/step - loss: 0.0020
# Epoch 9/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0020
# Epoch 10/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0019
# Epoch 11/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0019
# Epoch 12/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0019
# Epoch 13/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0018
# Epoch 14/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0018
# Epoch 15/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0018
# Epoch 16/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0018
# Epoch 17/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0017
# Epoch 18/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0017
# Epoch 19/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0017
# Epoch 20/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0017
# Epoch 21/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0016
# Epoch 22/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0016
# Epoch 23/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0016
# Epoch 24/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0016
# Epoch 25/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0015
# Epoch 26/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0015
# Epoch 27/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0015
# Epoch 28/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0015
# Epoch 29/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0014
# Epoch 30/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0014
# Epoch 31/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0014
# Epoch 32/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0013
# Epoch 33/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0013
# Epoch 34/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0013
# Epoch 35/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0013
# Epoch 36/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0012
# Epoch 37/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0012
# Epoch 38/300
# 271/271 [==============================] - 3s 12ms/step - loss: 0.0012
# Epoch 39/300
# 271/271 [==============================] - 5s 19ms/step - loss: 0.0012
# Epoch 40/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0012
# Epoch 41/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0011
# Epoch 42/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0011
# Epoch 43/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0011
# Epoch 44/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0011
# Epoch 45/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0011
# Epoch 46/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0010
# Epoch 47/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0010
# Epoch 48/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0010
# Epoch 49/300
# 271/271 [==============================] - 4s 14ms/step - loss: 0.0010
# Epoch 50/300
# 271/271 [==============================] - 4s 13ms/step - loss: 0.0010
# Epoch 51/300
# 271/271 [==============================] - 4s 13ms/step - loss: 9.7044e-04
# Epoch 52/300
# 271/271 [==============================] - 3s 13ms/step - loss: 0.0010
# Epoch 53/300
# 271/271 [==============================] - 3s 13ms/step - loss: 9.4708e-04
# Epoch 54/300
# 271/271 [==============================] - 3s 12ms/step - loss: 9.2752e-04
# Epoch 55/300
# 271/271 [==============================] - 3s 13ms/step - loss: 9.4541e-04
# Epoch 56/300
# 271/271 [==============================] - 4s 13ms/step - loss: 9.5746e-04
# Epoch 57/300
# 271/271 [==============================] - 3s 12ms/step - loss: 9.3773e-04
# Epoch 58/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.8917e-04
# Epoch 59/300
# 271/271 [==============================] - 4s 13ms/step - loss: 8.9182e-04
# Epoch 60/300
# 271/271 [==============================] - 4s 13ms/step - loss: 8.6994e-04
# Epoch 61/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.7277e-04
# Epoch 62/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.7446e-04
# Epoch 63/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.7109e-04
# Epoch 64/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.4083e-04
# Epoch 65/300
# 271/271 [==============================] - 4s 13ms/step - loss: 8.6117e-04
# Epoch 66/300
# 271/271 [==============================] - 3s 13ms/step - loss: 8.1775e-04
# Epoch 67/300
# 271/271 [==============================] - 4s 13ms/step - loss: 8.0019e-04
# Epoch 68/300
# 260/271 [===========================>..] - ETA: 0s - loss: 7.6802e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-a99ba91cfda7> in <module>()
# ----> 1 model.fit(X_train,y_train,epochs=300)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Training Evaluation

# %%
yhat_training = model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_train, yhat_training)
print('RMSE training',rms)

mae = mean_absolute_error(y_train, yhat_training)
print('MAE: training',mae)
# Out:
# RMSE training 0.0007697937784067926
# MAE: training 0.014350578828203115

# %%
y_data_inv = min_max_scaler.inverse_transform(y_train)
yhat_training_inv = min_max_scaler.inverse_transform(yhat_training)

mae_inv = mean_absolute_error(y_data_inv.T, yhat_training_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 0.4272196199402155

# %%
mae_inv = mean_absolute_error(y_data_inv.T[0], yhat_training_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 0.2654030845281637

# %%
plt.figure(figsize=[15,5])
plt.plot(y_data_inv.T[0])
plot = plt.plot(yhat_training_inv.T[0])
plt.ylim([0,20])
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %% [markdown]
# # Testing Evaluation

# %%
yhat_testing = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

rms = mean_squared_error(y_test, yhat_testing)
print('RMSE training',rms)

mae = mean_absolute_error(y_test, yhat_testing)
print('MAE: training',mae)
# Out:
# RMSE training 0.07489965752255774
# MAE: training 0.18093043012643584

# %%
y_test_inv = min_max_scaler.inverse_transform(y_test)
yhat_testing_inv = min_max_scaler.inverse_transform(yhat_testing)

mae_inv = mean_absolute_error(y_test_inv.T, yhat_testing_inv.T)
print('MAE training',mae_inv)
# Out:
# MAE training 6.859053758671557

# %%
mae_inv = mean_absolute_error(y_test_inv.T[0], yhat_testing_inv.T[0])
print('MAE training',mae_inv)
# Out:
# MAE training 2.2847805698373165

# %%
plt.figure(figsize=[15,5])
plt.plot(y_test_inv.T[0])
plot = plt.plot(yhat_testing_inv.T[0])
plt.ylim([0,35])
plt.xlim([0,1300])
# Out:
# (0.0, 1300.0)

# %% [markdown]
# # Model Comparison

# %% [markdown]
# For the evaluation of the models's performance we compare the MAE(Mean Absolute Error) values.<br>
# The MAE measures the average magnitude of the errors in a set of forecasts, without considering their direction. It measures accuracy for continuous variables. The equation is given in the library references. Expressed in words, the MAE is the average over the verification sample of the absolute values of the differences between forecast and the corresponding observation. The MAE is a linear score which means that all the individual differences are weighted equally in the average.
#
#
# MAE = $\frac{1}{N}\sum(y - \hat{y})$

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'CNN-LSTM':0.01664, 'CNN-FNN':0.01491, 'CNN-Bi-LSTM':0.01436,
        'CNN-Bi-GRU':0.01435, 'CNN-GRU':0.01390}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Model")
plt.ylabel("MAE")
plt.title("Training Evaluation")
plt.show()

# %%
# creating the dataset
data = {'CNN-Bi-LSTM':0.21004, 'CNN-LSTM':0.19137, 'CNN-FNN':0.18180, 
        'CNN-Bi-GRU':0.18093, 'CNN-GRU':0.17920}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='blue',
        width = 0.4)
 
plt.xlabel("Model")
plt.ylabel("MAE")
plt.title("Testing Evaluation")
plt.show()

# %% [markdown]
# So, we conclude that the model with the lowest MAE and the **best performance** is the **CNN-GRU**.

# %% [markdown]
# # AutoML

# %% [markdown]
# Automated machine learning (AutoML) is the process of automating the process of applying machine learning to real-world problems. AutoML covers the complete pipeline from the raw dataset to the deployable machine learning model. AutoML was proposed as an artificial intelligence-based solution to the ever-growing challenge of applying machine learning. The high degree of automation in AutoML allows non-experts to make use of machine learning models and techniques without requiring to become an expert in this field first.
#
# Automating the process of applying machine learning end-to-end additionally offers the advantages of producing simpler solutions, faster creation of those solutions, and models that often outperform hand-designed models.

# %% [markdown]
# The libary we use is H20.

# %% [markdown]
# Although H2O has made it easy for non-experts to experiment with machine learning, there is still a fair bit of knowledge and background in data science that is required to produce high-performing machine learning models. Deep Neural Networks in particular are notoriously difficult for a non-expert to tune properly. In order for machine learning software to truly be accessible to non-experts, we have designed an easy-to-use interface which automates the process of training a large selection of candidate models. H2O’s AutoML can also be a helpful tool for the advanced user, by providing a simple wrapper function that performs a large number of modeling-related tasks that would typically require many lines of code, and by freeing up their time to focus on other aspects of the data science pipeline tasks such as data-preprocessing, feature engineering and model deployment.

# %% [markdown]
# H2O’s AutoML can be used for automating the machine learning workflow, which includes automatic training and tuning of many models within a user-specified time-limit. Stacked Ensembles – one based on all previously trained models, another one on the best model of each family – will be automatically trained on collections of individual models to produce highly predictive ensemble models which, in most cases, will be the top performing models in the AutoML Leaderboard.

# %%
# !pip install h2o
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting h2o
#   Downloading h2o-3.36.1.2.tar.gz (177.0 MB)
#      |████████████████████████████████| 177.0 MB 43 kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from h2o) (2.23.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from h2o) (0.8.9)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from h2o) (0.16.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (1.24.3)
# Building wheels for collected packages: h2o
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.36.1.2-py2.py3-none-any.whl size=177070945 sha256=0ab1551b01e3b6741e56b273e24319c27697c0e396596ce1fd383ee4ae4e0d2e
#   Stored in directory: /root/.cache/pip/wheels/a5/2b/ae/534595df09001e1573b1046be62a3f049507307340119db65c
# Successfully built h2o
# Installing collected packages: h2o
# Successfully installed h2o-3.36.1.2

# %%
import h2o
from h2o.automl import H2OAutoML

# Start the H2O cluster (locally)
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.15" 2022-04-19; OpenJDK Runtime Environment (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1); OpenJDK 64-Bit Server VM (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpd0w8iqfz
#   JVM stdout: /tmp/tmpd0w8iqfz/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpd0w8iqfz/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         06 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.2
# H2O_cluster_version_age:    22 days
# H2O_cluster_name:           H2O_from_python_unknownUser_3qmute
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.172 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.13 final
# --------------------------  ----------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df =pd.read_csv("drive/My Drive/Elpida/2018Floor1.csv")

# %%
df = df.sort_values('Date') # sort the 'Date' column
df.head(5)
# Out:
#                   Date  z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  \
# 0  2018-07-01 00:00:00         12.94        18.56       45.24        0.01
# 1  2018-07-01 00:01:00         12.97        18.55       45.28        0.02
# 2  2018-07-01 00:02:00         12.97        18.55       45.24        0.01
# 3  2018-07-01 00:03:00         12.98        18.58       45.26        0.02
# 4  2018-07-01 00:04:00         13.01        18.60       45.22        0.02
#
#    z2_AC3(kW)  z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  \
# 0        0.01        0.00         13.76        17.64         10.92
# 1        0.01        0.01         13.76        17.21         10.95
# 2        0.01        0.01         13.79        17.18         10.94
# 3        0.01        0.00         13.81        16.64         10.94
# 4        0.01        0.01         13.83        15.69         10.97
#
#    z3_Plug(kW)  z4_Light(kW)
# 0         0.89         35.76
# 1         0.87         35.81
# 2         0.86         35.78
# 3         0.85         35.83
# 4         0.85         35.86

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.isnull().sum() # check if there are any null values
# Out:
# Date                0
# z1_Light(kW)     1461
# z1_Plug(kW)       486
# z2_AC1(kW)       1518
# z2_AC2(kW)       1457
# z2_AC3(kW)       1457
# z2_AC4(kW)       1457
# z2_Light(kW)     1434
# z2_Plug(kW)     29835
# z3_Light(kW)      514
# z3_Plug(kW)      1457
# z4_Light(kW)      515
# dtype: int64

# %% [markdown]
# Replacing the null values with mean.

# %%
updated_df = df
df['z1_Light(kW)']=df['z1_Light(kW)'].fillna(df['z1_Light(kW)'].mean())

df['z1_Plug(kW)']=df['z1_Plug(kW)'].fillna(df['z1_Plug(kW)'].mean())

df['z2_AC1(kW)']=df['z2_AC1(kW)'].fillna(df['z2_AC1(kW)'].mean())

df['z2_AC2(kW)']=df['z2_AC2(kW)'].fillna(df['z2_AC2(kW)'].mean())

df['z2_AC3(kW)']=df['z2_AC3(kW)'].fillna(df['z2_AC3(kW)'].mean())

df['z2_AC4(kW)']=df['z2_AC4(kW)'].fillna(df['z2_AC4(kW)'].mean())

df['z2_Light(kW)']=df['z2_Light(kW)'].fillna(df['z2_Light(kW)'].mean())

df['z2_Plug(kW)']=df['z2_Plug(kW)'].fillna(df['z2_Plug(kW)'].mean())

df['z3_Light(kW)']=df['z3_Light(kW)'].fillna(df['z3_Light(kW)'].mean())

df['z3_Plug(kW)']=df['z3_Plug(kW)'].fillna(df['z3_Plug(kW)'].mean())

df['z4_Light(kW)']=df['z4_Light(kW)'].fillna(df['z4_Light(kW)'].mean())

# %%
df['date'] =pd.to_datetime(df['Date'].dt.date)
update_df = df
update_df.drop(columns=['Date'])
# Out:
#         z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  z2_AC3(kW)  \
# 0              12.94        18.56       45.24        0.01        0.01
# 1              12.97        18.55       45.28        0.02        0.01
# 2              12.97        18.55       45.24        0.01        0.01
# 3              12.98        18.58       45.26        0.02        0.01
# 4              13.01        18.60       45.22        0.02        0.01
# ...              ...          ...         ...         ...         ...
# 264955          0.01         0.57       49.30        1.37        0.01
# 264956          0.01         0.57       45.44        1.36        0.01
# 264957          0.01         0.58        2.31        1.36        0.01
# 264958          0.02         0.57        2.31        1.35        0.00
# 264959          0.00         0.56        2.31        1.36        0.01
#
#         z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  z3_Plug(kW)  \
# 0             0.00         13.76        17.64         10.92         0.89
# 1             0.01         13.76        17.21         10.95         0.87
# 2             0.01         13.79        17.18         10.94         0.86
# 3             0.00         13.81        16.64         10.94         0.85
# 4             0.01         13.83        15.69         10.97         0.85
# ...            ...           ...          ...           ...          ...
# 264955        0.01         18.03        14.09         10.21         0.37
# 264956        0.00         17.72        11.37         10.13         0.38
# 264957        0.01         17.48        11.35         10.07         0.38
# 264958        0.00         17.43        11.39          9.99         0.37
# 264959        0.01         17.42        11.38         10.05         0.38
#
#         z4_Light(kW)       date
# 0              35.76 2018-07-01
# 1              35.81 2018-07-01
# 2              35.78 2018-07-01
# 3              35.83 2018-07-01
# 4              35.86 2018-07-01
# ...              ...        ...
# 264955         14.58 2018-12-31
# 264956         14.60 2018-12-31
# 264957         14.57 2018-12-31
# 264958         14.59 2018-12-31
# 264959         14.59 2018-12-31
#
# [264960 rows x 12 columns]

# %%
df_temp = df
df_temp['weekday'] = df_temp['Date'].dt.weekday
df_temp['hour'] = df_temp['Date'].dt.hour
df_temp['date'] =pd.to_datetime(df_temp['Date'].dt.date)

df_temp = df_temp.set_index('Date').drop(['date'],axis=1)

# %%
traindata = df_temp.loc[:'2018-12'].copy()
traindata = traindata.iloc[:,0:11]

testdata = df_temp.loc['2018-12':'2018-12'].copy()
testdata = testdata.iloc[:,0:11]

# %%
hf_train = h2o.H2OFrame(traindata)
hf_test = h2o.H2OFrame(testdata)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
hf_train.describe()
# Out:
# Rows:264960
# Cols:11
# <table>
# <thead>
# <tr><th>       </th><th>z1_Light(kW)      </th><th>z1_Plug(kW)      </th><th>z2_AC1(kW)        </th><th>z2_AC2(kW)        </th><th>z2_AC3(kW)          </th><th>z2_AC4(kW)          </th><th>z2_Light(kW)      </th><th>z2_Plug(kW)       </th><th>z3_Light(kW)      </th><th>z3_Plug(kW)       </th><th>z4_Light(kW)      </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>real              </td><td>real             </td><td>real              </td><td>real              </td><td>real                </td><td>real                </td><td>real              </td><td>real              </td><td>real              </td><td>real              </td><td>real              </td></tr>
# <tr><td>mins   </td><td>0.0               </td><td>0.0              </td><td>0.01              </td><td>0.0               </td><td>0.0                 </td><td>0.0                 </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>0.0               </td></tr>
# <tr><td>mean   </td><td>6.3884013222061915</td><td>4.182151515839015</td><td>29.007512014029675</td><td>4.769191811857918 </td><td>0.009434010238972643</td><td>0.007445645780123978</td><td>14.754282613480294</td><td>15.625257969165364</td><td>23.582279709278946</td><td>1.163607093657382 </td><td>17.114396566393747</td></tr>
# <tr><td>maxs   </td><td>134.97            </td><td>57.86            </td><td>131.55            </td><td>798.72            </td><td>24.95               </td><td>0.06                </td><td>55.28             </td><td>55.12             </td><td>4762.43           </td><td>22.22             </td><td>512.01            </td></tr>
# <tr><td>sigma  </td><td>8.734302430928366 </td><td>6.931909984543836</td><td>22.03573540281819 </td><td>12.336243356658331</td><td>0.04864611572907894 </td><td>0.008254972015487564</td><td>3.1445117661958495</td><td>2.4451914898939258</td><td>16.821179308539637</td><td>0.7177492189653293</td><td>18.499954971686588</td></tr>
# <tr><td>zeros  </td><td>33004             </td><td>1433             </td><td>0                 </td><td>941               </td><td>34135               </td><td>116397              </td><td>9                 </td><td>2                 </td><td>6                 </td><td>18                </td><td>84                </td></tr>
# <tr><td>missing</td><td>0                 </td><td>0                </td><td>0                 </td><td>0                 </td><td>0                   </td><td>0                   </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0                 </td></tr>
# <tr><td>0      </td><td>12.94             </td><td>18.56            </td><td>45.24             </td><td>0.01              </td><td>0.01                </td><td>0.0                 </td><td>13.76             </td><td>17.64             </td><td>10.92             </td><td>0.89              </td><td>35.76             </td></tr>
# <tr><td>1      </td><td>12.97             </td><td>18.55            </td><td>45.28             </td><td>0.02              </td><td>0.01                </td><td>0.01                </td><td>13.76             </td><td>17.21             </td><td>10.95             </td><td>0.87              </td><td>35.81             </td></tr>
# <tr><td>2      </td><td>12.97             </td><td>18.55            </td><td>45.24             </td><td>0.01              </td><td>0.01                </td><td>0.01                </td><td>13.79             </td><td>17.18             </td><td>10.94             </td><td>0.86              </td><td>35.78             </td></tr>
# <tr><td>3      </td><td>12.98             </td><td>18.58            </td><td>45.26             </td><td>0.02              </td><td>0.01                </td><td>0.0                 </td><td>13.81             </td><td>16.64             </td><td>10.94             </td><td>0.85              </td><td>35.83             </td></tr>
# <tr><td>4      </td><td>13.01             </td><td>18.6             </td><td>45.22             </td><td>0.02              </td><td>0.01                </td><td>0.01                </td><td>13.83             </td><td>15.69             </td><td>10.97             </td><td>0.85              </td><td>35.86             </td></tr>
# <tr><td>5      </td><td>12.98             </td><td>18.55            </td><td>45.21             </td><td>0.01              </td><td>0.01                </td><td>0.01                </td><td>13.81             </td><td>15.68             </td><td>10.97             </td><td>0.83              </td><td>35.83             </td></tr>
# <tr><td>6      </td><td>12.97             </td><td>18.56            </td><td>45.19             </td><td>0.02              </td><td>0.01                </td><td>0.0                 </td><td>13.81             </td><td>15.61             </td><td>10.93             </td><td>0.82              </td><td>35.81             </td></tr>
# <tr><td>7      </td><td>12.98             </td><td>18.64            </td><td>45.12             </td><td>0.01              </td><td>0.01                </td><td>0.01                </td><td>13.79             </td><td>15.79             </td><td>10.95             </td><td>0.82              </td><td>35.84             </td></tr>
# <tr><td>8      </td><td>12.99             </td><td>18.65            </td><td>45.11             </td><td>0.02              </td><td>0.01                </td><td>0.0                 </td><td>13.82             </td><td>17.42             </td><td>10.96             </td><td>0.82              </td><td>35.84             </td></tr>
# <tr><td>9      </td><td>13.0              </td><td>18.66            </td><td>45.19             </td><td>0.02              </td><td>0.01                </td><td>0.01                </td><td>13.83             </td><td>17.72             </td><td>10.95             </td><td>0.8               </td><td>35.86             </td></tr>
# </tbody>
# </table>

# %% [markdown]
# Select response and features
#
# y: target signal
#
# X: feature matrix with lagged values

# %%
y = 'z1_Light(kW)'
X = hf_train.columns
X.remove(y)

# %%
X
# Out:
# ['z1_Plug(kW)',
#  'z2_AC1(kW)',
#  'z2_AC2(kW)',
#  'z2_AC3(kW)',
#  'z2_AC4(kW)',
#  'z2_Light(kW)',
#  'z2_Plug(kW)',
#  'z3_Light(kW)',
#  'z3_Plug(kW)',
#  'z4_Light(kW)']

# %%
aml = H2OAutoML(max_runtime_secs = 600,
                seed = 42)
aml.train(x = X, 
          y = y,
          training_frame = hf_train,
          leaderboard_frame = hf_test)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_1_AutoML_1_20220618_110323
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.42000925010401013
# RMSE: 0.6480812064116734
# MAE: 0.31936815844112926
# RMSLE: NaN
# R^2: 0.9943492619298693
# Mean Residual Deviance: 0.42000925010401013
# Null degrees of freedom: 9929
# Residual degrees of freedom: 9925
# Null deviance: 738218.9412652634
# Residual deviance: 4170.6918535328205
# AIC: 19578.057328616283
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on validation data. **
#
# MSE: 2.060827698466948
# RMSE: 1.4355583229067874
# MAE: 0.5417691084168432
# RMSLE: NaN
# R^2: 0.9730392497479199
# Mean Residual Deviance: 2.060827698466948
# Null degrees of freedom: 26316
# Residual degrees of freedom: 26312
# Null deviance: 2011769.2119536565
# Residual deviance: 54234.80254055467
# AIC: 93726.4360311614

# %% [markdown]
# Check the leaderboard
#
# - models are ranked by peformance on the test data since we specified a leadboard_frame

# %%
lb = aml.leaderboard

lb
# Out:
# <table>
# <thead>
# <tr><th>model_id                                               </th><th style="text-align: right;">   rmse</th><th style="text-align: right;">    mse</th><th style="text-align: right;">     mae</th><th style="text-align: right;">     rmsle</th><th style="text-align: right;">  mean_residual_deviance</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_1_20220618_110323   </td><td style="text-align: right;">1.28887</td><td style="text-align: right;">1.6612 </td><td style="text-align: right;">0.443452</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 1.6612 </td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_2_AutoML_1_20220618_110323</td><td style="text-align: right;">1.28984</td><td style="text-align: right;">1.66369</td><td style="text-align: right;">0.444405</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 1.66369</td></tr>
# <tr><td>XGBoost_1_AutoML_1_20220618_110323                     </td><td style="text-align: right;">1.32655</td><td style="text-align: right;">1.75975</td><td style="text-align: right;">0.53177 </td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 1.75975</td></tr>
# <tr><td>DRF_1_AutoML_1_20220618_110323                         </td><td style="text-align: right;">1.4294 </td><td style="text-align: right;">2.04318</td><td style="text-align: right;">0.378681</td><td style="text-align: right;">  0.308477</td><td style="text-align: right;">                 2.04318</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_1_AutoML_1_20220618_110323</td><td style="text-align: right;">1.43864</td><td style="text-align: right;">2.06969</td><td style="text-align: right;">0.555961</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 2.06969</td></tr>
# <tr><td>XGBoost_2_AutoML_1_20220618_110323                     </td><td style="text-align: right;">1.85527</td><td style="text-align: right;">3.44202</td><td style="text-align: right;">0.81026 </td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 3.44202</td></tr>
# <tr><td>GBM_1_AutoML_1_20220618_110323                         </td><td style="text-align: right;">1.994  </td><td style="text-align: right;">3.97604</td><td style="text-align: right;">0.834594</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 3.97604</td></tr>
# <tr><td>GBM_4_AutoML_1_20220618_110323                         </td><td style="text-align: right;">2.14552</td><td style="text-align: right;">4.60327</td><td style="text-align: right;">0.851274</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 4.60327</td></tr>
# <tr><td>GBM_3_AutoML_1_20220618_110323                         </td><td style="text-align: right;">2.461  </td><td style="text-align: right;">6.0565 </td><td style="text-align: right;">1.05842 </td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 6.0565 </td></tr>
# <tr><td>GBM_2_AutoML_1_20220618_110323                         </td><td style="text-align: right;">2.94318</td><td style="text-align: right;">8.66232</td><td style="text-align: right;">1.34264 </td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 8.66232</td></tr>
# </tbody>
# </table>

# %% [markdown]
# Select the top model

# %%
leader_model = aml.leader

# %% [markdown]
# Make predictions on the test data

# %%
hf_test_predict = leader_model.predict(hf_test)
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%

# %%
hf_test_predict.head(5)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  12.5518</td></tr>
# <tr><td style="text-align: right;">  13.3239</td></tr>
# <tr><td style="text-align: right;">  14.8031</td></tr>
# <tr><td style="text-align: right;">  11.3845</td></tr>
# <tr><td style="text-align: right;">  14.3361</td></tr>
# </tbody>
# </table>

# %%
df_results = pd.DataFrame()
df_results['ground_truth'] = testdata['z1_Light(kW)'].reset_index(drop=True)
df_results['predictions'] = h2o.as_list(hf_test_predict,use_pandas=True)
df_results.head()
# Out:
#    ground_truth  predictions
# 0         13.25    12.551835
# 1         13.12    13.323897
# 2         15.32    14.803148
# 3         10.94    11.384490
# 4         15.32    14.336147

# %% [markdown]
# Get R2 for this prediction

# %%
from scipy import stats

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(x=df_results['predictions'],y=df_results['ground_truth'])
print('R2 = ',r_value*r_value)
# Out:
# R2 =  0.967770215886844

# %%
plt.figure(figsize=[15,5])
plt.plot(df_results['ground_truth'])
plt.plot(df_results['predictions'])
plt.ylabel('pollution',fontsize=18)
plt.legend(['ground_truth','prediction'])
plt.show()

# %% [markdown]
# # Thank you for your time
